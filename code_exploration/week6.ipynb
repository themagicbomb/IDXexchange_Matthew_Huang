# %% [markdown]
# Price Ratio: ClosePrice / OriginalListPrice; Measures negotiation strength
#
# Price Per Sq Ft: ClosePrice / LivingArea; Normalizes price across sizes
#
# Days on Market: DaysOnMarket (raw field); Time-to-sell indicator
#
# Year / Month / YrMo: Derived from CloseDate; Enables time-series analysis
#
# Close to Original List Ratio: ClosePrice / OriginalListPrice; Captures full price reduction history
#
# Listing to Contract Days: PurchaseContractDate - ListingContractDate; Measures time from listing to accepted offer
#
# Contract to Close Days: CloseDate - PurchaseContractDate; Escrow and closing period duration

# %%
import pandas as pd

# %%
listing = pd.read_csv("data/listing_prepared.csv", low_memory=False)
sold = pd.read_csv("data/sold_prepared.csv", low_memory=False)

# %%
listing["Price Ratio"] = listing["ClosePrice"] / listing["OriginalListPrice"]
sold["Price Ratio"] = sold["ClosePrice"] / sold["OriginalListPrice"]

listing["Price Per Sq Ft"] = listing["ClosePrice"] / listing["LivingArea"]
sold["Price Per Sq Ft"] = sold["ClosePrice"] / sold["LivingArea"]

listing["Days on Market"] = listing["DaysOnMarket"]
sold["Days on Market"] = sold["DaysOnMarket"]

listing["CloseDate"] = pd.to_datetime(listing["CloseDate"])
sold["CloseDate"] = pd.to_datetime(sold["CloseDate"])
listing["Year"] = listing["CloseDate"].dt.year.astype("Int64")
sold["Year"] = sold["CloseDate"].dt.year.astype("Int64")
listing["Month"] = listing["CloseDate"].dt.month.astype("Int64")
sold["Month"] = sold["CloseDate"].dt.month.astype("Int64")
listing["YrMo"] = listing["CloseDate"].dt.to_period("M")
sold["YrMo"] = sold["CloseDate"].dt.to_period("M")

listing["Close to Original List Ratio"] = listing["ClosePrice"] / listing["OriginalListPrice"]
sold["Close to Original List Ratio"] = sold["ClosePrice"] / sold["OriginalListPrice"]

listing["PurchaseContractDate"] = pd.to_datetime(listing["PurchaseContractDate"])
listing["ListingContractDate"] = pd.to_datetime(listing["ListingContractDate"])
sold["PurchaseContractDate"] = pd.to_datetime(sold["PurchaseContractDate"])
sold["ListingContractDate"] = pd.to_datetime(sold["ListingContractDate"])
listing["Listing to Contract Days"] = listing["PurchaseContractDate"] - listing["ListingContractDate"]
sold["Listing to Contract Days"] = sold["PurchaseContractDate"] - sold["ListingContractDate"]

listing["Contract to Close Days"] =listing["CloseDate"] - listing["PurchaseContractDate"]
sold["Contract to Close Days"] =sold["CloseDate"] - sold["PurchaseContractDate"]

# %%
print("Sample Output of new column calculations (from Listing):")

print(listing[["Price Ratio", "ClosePrice", "OriginalListPrice", "Price Per Sq Ft", "ClosePrice", "LivingArea", "Days on Market", "DaysOnMarket", "Year", "Month" , "YrMo", "CloseDate", "Close to Original List Ratio", "ClosePrice", "OriginalListPrice", "Listing to Contract Days", "PurchaseContractDate", "ListingContractDate", "Contract to Close Days", "CloseDate", "PurchaseContractDate"]].dropna().head())
# Out:
# Sample Output of new column calculations (from Listing):
#     Price Ratio  ClosePrice  OriginalListPrice  Price Per Sq Ft  ClosePrice  \
# 9      1.010135   1262555.0          1249888.0       664.852554   1262555.0
# 14     1.000000    650000.0           650000.0       464.285714    650000.0
# 18     0.939024    962500.0          1025000.0       851.769912    962500.0
# 20     1.000000    725000.0           725000.0       580.000000    725000.0
# 33     1.000000    730000.0           730000.0       576.619273    730000.0
#
#     LivingArea  Days on Market  DaysOnMarket  Year  Month  ...  CloseDate  \
# 9       1899.0               0             0  2024      5  ... 2024-05-01
# 14      1400.0               0             0  2024      3  ... 2024-03-15
# 18      1130.0               0             0  2024      5  ... 2024-05-02
# 20      1250.0               0             0  2024      4  ... 2024-04-30
# 33      1266.0              35            35  2024      4  ... 2024-04-09
#
#    Close to Original List Ratio  ClosePrice  OriginalListPrice  \
# 9                      1.010135   1262555.0          1249888.0
# 14                     1.000000    650000.0           650000.0
# 18                     0.939024    962500.0          1025000.0
# 20                     1.000000    725000.0           725000.0
# 33                     1.000000    730000.0           730000.0
#
#     Listing to Contract Days PurchaseContractDate ListingContractDate  \
# 9                    20 days           2024-02-18          2024-01-29
# 14                   10 days           2024-02-01          2024-01-22
# 18                  104 days           2024-04-30          2024-01-17
# 20                   18 days           2024-02-09          2024-01-22
# 33                   35 days           2024-02-11          2024-01-07
#
#    Contract to Close Days  CloseDate PurchaseContractDate
# 9                 73 days 2024-05-01           2024-02-18
# 14                43 days 2024-03-15           2024-02-01
# 18                 2 days 2024-05-02           2024-04-30
# 20                81 days 2024-04-30           2024-02-09
# 33                58 days 2024-04-09           2024-02-11
#
# [5 rows x 21 columns]

# %% [markdown]
# After creating your engineered metrics, group the analysis by key dimensions to uncover market patterns.
# Generate summary statistics for each segment:
# - • PropertyType and PropertySubType
# - • CountyOrParish and MLSAreaMajor
# - • ListOfficeName and BuyerOfficeName (for competitive intelligence)

# %% [markdown]
# Submit a .py script demonstrating all engineered metrics (price ratio, close-to-original-list ratio, PPSF, days on market, YrMo, listing-to-contract days, contract-to-close days), with a sample output table showing the new columns populated correctly. Include at least one segmented summary table grouped by
# PropertyType or CountyOrParish.

# %%
print("Listing Metrics Grouped by PropertySubType (all PropertyType is Residential):")
print(listing.groupby("PropertySubType")[["Price Ratio", "Price Per Sq Ft", "Days on Market", "Year", "Month", "YrMo", "Close to Original List Ratio", "Listing to Contract Days", "Contract to Close Days"]].describe().T)
print()

print("Sold Metrics Grouped by PropertySubType (all PropertyType is Residential):")
print(sold.groupby("PropertySubType")[["Price Ratio", "Price Per Sq Ft", "Days on Market", "Year", "Month", "YrMo", "Close to Original List Ratio", "Listing to Contract Days", "Contract to Close Days"]].describe().T)
print()
# Out:
# Listing Grouped by PropertySubType (all PropertyType is Residential):
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# PropertySubType              Apartment          BoatSlip              Cabin  \
# Price Ratio            count       0.0              36.0              125.0
#                        mean        NaN          0.945205           0.900549
#                        std         NaN           0.07249            0.14107
#                        min         NaN          0.755882           0.371429
#                        25%         NaN          0.918731           0.856031
# ...                                ...               ...                ...
# Contract to Close Days min         NaT   0 days 00:00:00    0 days 00:00:00
#                        25%         NaT   9 days 00:00:00   18 days 00:00:00
#                        50%         NaT  13 days 12:00:00   26 days 00:00:00
#                        75%         NaT  20 days 00:00:00   34 days 00:00:00
#                        max         NaT  40 days 00:00:00  129 days 00:00:00
#
# PropertySubType                    CoOwnership        Condominium  \
# Price Ratio            count               4.0            23656.0
#                        mean           1.265876          27.359098
#                        std            0.556711        3901.515059
#                        min            0.952381           0.000929
#                        25%            0.984534           0.963812
# ...                                        ...                ...
# Contract to Close Days min    21 days 00:00:00    0 days 00:00:00
#                        25%    28 days 12:00:00   17 days 00:00:00
#                        50%    35 days 12:00:00   25 days 00:00:00
#                        75%    44 days 18:00:00   32 days 00:00:00
#                        max    59 days 00:00:00  396 days 00:00:00
#
# PropertySubType                  DeededParking             Duplex  \
# Price Ratio            count               3.0              713.0
#                        mean           0.959257            1.00515
#                        std            0.058889           0.337348
#                        min                 0.9            0.58875
#                        25%                0.93           0.955556
# ...                                        ...                ...
# Contract to Close Days min     3 days 00:00:00    0 days 00:00:00
#                        25%    17 days 00:00:00   19 days 00:00:00
#                        50%    31 days 00:00:00   28 days 00:00:00
#                        75%    35 days 12:00:00   39 days 00:00:00
#                        max    40 days 00:00:00  189 days 00:00:00
#
# PropertySubType                           Farm              Loft  \
# Price Ratio            count               2.0               4.0
#                        mean           0.909713          1.006544
#                        std            0.128392          0.034115
#                        min            0.818926           0.97143
#                        25%             0.86432          0.992857
# ...                                        ...               ...
# Contract to Close Days min     0 days 00:00:00  14 days 00:00:00
#                        25%    20 days 00:00:00  18 days 12:00:00
#                        50%    29 days 12:00:00  29 days 00:00:00
#                        75%    30 days 12:00:00  34 days 06:00:00
#                        max    81 days 00:00:00  43 days 00:00:00
#
# PropertySubType               ManufacturedHome  ...          MixedUse  \
# Price Ratio            count              13.0  ...              48.0
#                        mean           0.999179  ...          0.960494
#                        std            0.051982  ...          0.088605
#                        min            0.927318  ...          0.679744
#                        25%            0.959596  ...          0.917401
# ...                                        ...  ...               ...
# Contract to Close Days min    13 days 00:00:00  ...   0 days 00:00:00
#                        25%    23 days 00:00:00  ...  11 days 18:00:00
#                        50%    26 days 00:00:00  ...  23 days 00:00:00
#                        75%    41 days 00:00:00  ...  31 days 06:00:00
#                        max    95 days 00:00:00  ...  72 days 00:00:00
#
# PropertySubType                     MobileHome        OwnYourOwn  \
# Price Ratio            count              14.0              18.0
#                        mean            0.94453          0.961642
#                        std            0.036242          0.078674
#                        min            0.862069          0.728597
#                        25%            0.915116          0.928035
# ...                                        ...               ...
# Contract to Close Days min     1 days 00:00:00   0 days 00:00:00
#                        25%     2 days 00:00:00  17 days 06:00:00
#                        50%     2 days 00:00:00  25 days 12:00:00
#                        75%     7 days 18:00:00  29 days 00:00:00
#                        max    21 days 00:00:00  46 days 00:00:00
#
# PropertySubType                     Quadruplex SingleFamilyResidence  \
# Price Ratio            count              44.0              109686.0
#                        mean           1.160779                   inf
#                        std            1.313831                   NaN
#                        min            0.633333              0.000667
#                        25%            0.918704               0.96938
# ...                                        ...                   ...
# Contract to Close Days min     0 days 00:00:00       0 days 00:00:00
#                        25%    16 days 00:00:00      18 days 00:00:00
#                        50%    24 days 00:00:00      25 days 00:00:00
#                        75%    34 days 06:00:00      32 days 00:00:00
#                        max    72 days 00:00:00    1484 days 00:00:00
#
# PropertySubType                StockCooperative            Studio  \
# Price Ratio            count              443.0               2.0
#                        mean            0.981204          0.970238
#                        std             0.053806           0.04209
#                        min             0.747945          0.940476
#                        25%             0.958159          0.955357
# ...                                         ...               ...
# Contract to Close Days min      0 days 00:00:00  31 days 00:00:00
#                        25%     38 days 00:00:00  31 days 12:00:00
#                        50%     45 days 00:00:00  32 days 00:00:00
#                        75%     52 days 00:00:00  32 days 12:00:00
#                        max    104 days 00:00:00  33 days 00:00:00
#
# PropertySubType                      Timeshare          Townhouse  \
# Price Ratio            count               9.0             8892.0
#                        mean           0.991118           1.474298
#                        std            0.011603            21.9146
#                        min            0.969512           0.000932
#                        25%            0.981818           0.973588
# ...                                        ...                ...
# Contract to Close Days min     8 days 00:00:00    0 days 00:00:00
#                        25%    10 days 00:00:00   20 days 00:00:00
#                        50%    14 days 00:00:00   26 days 00:00:00
#                        75%    18 days 00:00:00   31 days 00:00:00
#                        max    46 days 00:00:00  461 days 00:00:00
#
# PropertySubType                         Triplex
# Price Ratio            count              100.0
#                        mean            1.066684
#                        std              0.90704
#                        min             0.654545
#                        25%             0.949109
# ...                                         ...
# Contract to Close Days min      0 days 00:00:00
#                        25%     19 days 18:00:00
#                        50%     35 days 12:00:00
#                        75%     51 days 06:00:00
#                        max    126 days 00:00:00
#
# [64 rows x 21 columns]
#
# Sold Grouped by PropertySubType (all PropertyType is Residential):
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# PropertySubType                        BoatSlip              Cabin  \
# Price Ratio            count               82.0              470.0
#                        mean            0.912406           0.897239
#                        std             0.125733           0.297923
#                        min             0.086486           0.090909
#                        25%             0.877592           0.816159
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    0 days 00:00:00
#                        25%     12 days 00:00:00   21 days 00:00:00
#                        50%     17 days 00:00:00   30 days 00:00:00
#                        75%     23 days 18:00:00   41 days 00:00:00
#                        max    101 days 00:00:00  360 days 00:00:00
#
# PropertySubType                     CoOwnership        Condominium  \
# Price Ratio            count               18.0            68326.0
#                        mean           56.533748          25.785909
#                        std           235.515026        4300.455621
#                        min                 0.88           0.000536
#                        25%             0.938824           0.950945
# ...                                         ...                ...
# Contract to Close Days min     11 days 00:00:00    0 days 00:00:00
#                        25%     31 days 12:00:00   20 days 00:00:00
#                        50%     41 days 00:00:00   28 days 00:00:00
#                        75%     58 days 12:00:00   35 days 00:00:00
#                        max    150 days 00:00:00  923 days 00:00:00
#
# PropertySubType                  DeededParking             Duplex  \
# Price Ratio            count               6.0             2261.0
#                        mean           0.837471         431.433321
#                        std            0.415283       20446.306551
#                        min               0.001              0.096
#                        25%               0.915            0.93054
# ...                                        ...                ...
# Contract to Close Days min     3 days 00:00:00    0 days 00:00:00
#                        25%    23 days 06:00:00   23 days 00:00:00
#                        50%    27 days 12:00:00   32 days 00:00:00
#                        75%    37 days 18:00:00   45 days 00:00:00
#                        max    48 days 00:00:00  352 days 00:00:00
#
# PropertySubType                            Farm               Loft  \
# Price Ratio            count               14.0               28.0
#                        mean            0.971151           0.983485
#                        std             0.108285           0.055823
#                        min             0.791667           0.874074
#                        25%             0.897107            0.96462
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00   13 days 00:00:00
#                        25%     22 days 00:00:00   21 days 18:00:00
#                        50%     29 days 00:00:00   33 days 12:00:00
#                        75%     81 days 00:00:00   43 days 06:00:00
#                        max    461 days 00:00:00  110 days 00:00:00
#
# PropertySubType                ManufacturedHome  ManufacturedOnLand  \
# Price Ratio            count               40.0              5339.0
#                        mean            0.951788            1.290423
#                        std              0.07121              17.578
#                        min             0.685393             0.00098
#                        25%             0.923673            0.905278
# ...                                         ...                 ...
# Contract to Close Days min     13 days 00:00:00     0 days 00:00:00
#                        25%     23 days 00:00:00    24 days 00:00:00
#                        50%     30 days 00:00:00    34 days 00:00:00
#                        75%     49 days 00:00:00    48 days 00:00:00
#                        max    120 days 00:00:00  1281 days 00:00:00
#
# PropertySubType                        MixedUse        MobileHome  \
# Price Ratio            count              207.0              37.0
#                        mean            0.888575          0.916272
#                        std             0.159917           0.06862
#                        min             0.008891          0.714286
#                        25%             0.824136          0.890869
# ...                                         ...               ...
# Contract to Close Days min      0 days 00:00:00   1 days 00:00:00
#                        25%     22 days 00:00:00   2 days 00:00:00
#                        50%     32 days 00:00:00   7 days 00:00:00
#                        75%     60 days 12:00:00  13 days 00:00:00
#                        max    557 days 00:00:00  62 days 00:00:00
#
# PropertySubType                      OwnYourOwn         Quadruplex  \
# Price Ratio            count               57.0              142.0
#                        mean            0.928699           0.990613
#                        std             0.106041           0.741368
#                        min             0.606061           0.586552
#                        25%             0.879397           0.875453
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    0 days 00:00:00
#                        25%     20 days 00:00:00   24 days 00:00:00
#                        50%     29 days 00:00:00   36 days 00:00:00
#                        75%     38 days 00:00:00   53 days 00:00:00
#                        max    181 days 00:00:00  227 days 00:00:00
#
# PropertySubType              SingleFamilyResidence   StockCooperative  \
# Price Ratio            count              308822.0             1663.0
#                        mean                    inf           1.547396
#                        std                     NaN          23.447189
#                        min                0.000001           0.451111
#                        25%                0.954242           0.948334
# ...                                            ...                ...
# Contract to Close Days min         0 days 00:00:00    0 days 00:00:00
#                        25%        21 days 00:00:00   39 days 12:00:00
#                        50%        29 days 00:00:00   45 days 00:00:00
#                        75%        36 days 00:00:00   53 days 00:00:00
#                        max      1970 days 00:00:00  293 days 00:00:00
#
# PropertySubType                         Studio          Timeshare  \
# Price Ratio            count              11.0               18.0
#                        mean             0.9573           0.908823
#                        std            0.045511           0.171004
#                        min            0.909091           0.454545
#                        25%            0.921088           0.958566
# ...                                        ...                ...
# Contract to Close Days min    10 days 00:00:00    0 days 00:00:00
#                        25%    31 days 12:00:00   10 days 00:00:00
#                        50%    33 days 00:00:00   18 days 00:00:00
#                        75%    44 days 00:00:00   36 days 18:00:00
#                        max    77 days 00:00:00  112 days 00:00:00
#
# PropertySubType                       Townhouse            Triplex
# Price Ratio            count            24236.0              339.0
#                        mean           41.533218           1.027633
#                        std          6201.457567           0.863878
#                        min             0.000932           0.497143
#                        25%             0.966611           0.897144
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    0 days 00:00:00
#                        25%     21 days 00:00:00   26 days 12:00:00
#                        50%     28 days 00:00:00   36 days 00:00:00
#                        75%     34 days 00:00:00   50 days 00:00:00
#                        max    535 days 00:00:00  605 days 00:00:00
#
# [64 rows x 20 columns]

# %%
#- • CountyOrParish and MLSAreaMajor
listing["MLSAreaMajor"].value_counts() # 1108 unique values...
listing["CountyOrParish"].value_counts() # 63! Managable!

print("Listing Metrics Grouped by CountyOrParish:")
print(listing.groupby("CountyOrParish")[["Price Ratio", "Price Per Sq Ft", "Days on Market", "Year", "Month", "YrMo", "Close to Original List Ratio", "Listing to Contract Days", "Contract to Close Days"]].describe().T)
print()

print("Sold Metrics Grouped by CountyOrParish:")
print(sold.groupby("CountyOrParish")[["Price Ratio", "Price Per Sq Ft", "Days on Market", "Year", "Month", "YrMo", "Close to Original List Ratio", "Listing to Contract Days", "Contract to Close Days"]].describe().T)
print()
# Out:
# Listing Grouped by CountyOrParish:
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# CountyOrParish                          Alameda Alpine            Amador  \
# Price Ratio            count             8502.0    0.0               6.0
#                        mean            1.202311    NaN          0.854278
#                        std            11.898197    NaN          0.192551
#                        min             0.000667    NaN          0.514032
#                        25%             0.990441    NaN          0.786784
# ...                                         ...    ...               ...
# Contract to Close Days min      0 days 00:00:00    NaT  14 days 00:00:00
#                        25%     16 days 00:00:00    NaT  24 days 12:00:00
#                        50%     22 days 00:00:00    NaT  30 days 00:00:00
#                        75%     29 days 00:00:00    NaT  34 days 12:00:00
#                        max    396 days 00:00:00    NaT  50 days 00:00:00
#
# CountyOrParish                            Butte         Calaveras  \
# Price Ratio            count             1337.0              22.0
#                        mean            1.733049          0.956742
#                        std            27.819314          0.060806
#                        min             0.105882          0.767692
#                        25%             0.953757          0.937288
# ...                                         ...               ...
# Contract to Close Days min      0 days 00:00:00   0 days 00:00:00
#                        25%     21 days 00:00:00  19 days 12:00:00
#                        50%     28 days 00:00:00  28 days 12:00:00
#                        75%     34 days 00:00:00  41 days 12:00:00
#                        max    119 days 00:00:00  92 days 00:00:00
#
# CountyOrParish                          Clark            Colusa  \
# Price Ratio            count              1.0              11.0
#                        mean          0.974026          1.012478
#                        std                NaN           0.02754
#                        min           0.974026          0.966316
#                        25%           0.974026               1.0
# ...                                       ...               ...
# Contract to Close Days min    9 days 00:00:00  10 days 00:00:00
#                        25%    9 days 00:00:00  17 days 00:00:00
#                        50%    9 days 00:00:00  20 days 00:00:00
#                        75%    9 days 00:00:00  32 days 06:00:00
#                        max    9 days 00:00:00  52 days 00:00:00
#
# CountyOrParish                      Contra Costa Del Norte         El Dorado  \
# Price Ratio            count              8161.0       0.0              27.0
#                        mean             1.015928       NaN          0.995065
#                        std              0.093631       NaN          0.091254
#                        min              0.000912       NaN          0.844444
#                        25%              0.975163       NaN          0.975345
# ...                                          ...       ...               ...
# Contract to Close Days min       0 days 00:00:00       NaT   0 days 00:00:00
#                        25%      16 days 00:00:00       NaT  20 days 00:00:00
#                        50%      22 days 00:00:00       NaT  28 days 00:00:00
#                        75%      29 days 00:00:00       NaT  31 days 18:00:00
#                        max    1484 days 00:00:00       NaT  88 days 00:00:00
#
# CountyOrParish                ...            Sonoma         Stanislaus  \
# Price Ratio            count  ...              44.0              194.0
#                        mean   ...          1.020122           0.995395
#                        std    ...          0.195869           0.212579
#                        min    ...          0.851703           0.258065
#                        25%    ...          0.961528           0.965061
# ...                           ...               ...                ...
# Contract to Close Days min    ...   0 days 00:00:00    0 days 00:00:00
#                        25%    ...  17 days 18:00:00   20 days 00:00:00
#                        50%    ...  22 days 00:00:00   26 days 00:00:00
#                        75%    ...  30 days 00:00:00   31 days 00:00:00
#                        max    ...  92 days 00:00:00  113 days 00:00:00
#
# CountyOrParish                          Sutter            Tehama  \
# Price Ratio            count              29.0              95.0
#                        mean           0.989111          0.975382
#                        std            0.234831          0.136968
#                        min            0.099338          0.609137
#                        25%            0.969529          0.923803
# ...                                        ...               ...
# Contract to Close Days min     4 days 00:00:00   0 days 00:00:00
#                        25%    21 days 00:00:00  22 days 12:00:00
#                        50%    26 days 00:00:00  30 days 00:00:00
#                        75%    34 days 00:00:00  38 days 00:00:00
#                        max    48 days 00:00:00  86 days 00:00:00
#
# CountyOrParish                         Trinity            Tulare  \
# Price Ratio            count               6.0             139.0
#                        mean           0.968135          7.227134
#                        std            0.082714         73.672652
#                        min            0.877193          0.093633
#                        25%             0.92028          0.967608
# ...                                        ...               ...
# Contract to Close Days min    11 days 00:00:00   0 days 00:00:00
#                        25%    31 days 00:00:00  20 days 00:00:00
#                        50%    40 days 12:00:00  30 days 00:00:00
#                        75%    72 days 12:00:00  38 days 00:00:00
#                        max    95 days 00:00:00  75 days 00:00:00
#
# CountyOrParish                        Tuolumne            Ventura  \
# Price Ratio            count              14.0             4525.0
#                        mean           0.887063           1.979099
#                        std            0.197857          33.383406
#                        min            0.238095              0.001
#                        25%            0.888628           0.963705
# ...                                        ...                ...
# Contract to Close Days min     0 days 00:00:00    0 days 00:00:00
#                        25%    19 days 00:00:00    8 days 00:00:00
#                        50%    25 days 00:00:00   21 days 00:00:00
#                        75%    32 days 00:00:00   31 days 00:00:00
#                        max    55 days 00:00:00  142 days 00:00:00
#
# CountyOrParish                            Yolo               Yuba
# Price Ratio            count              28.0               40.0
#                        mean            1.00297           0.968357
#                        std            0.121774           0.056463
#                        min            0.841751           0.791367
#                        25%            0.953677           0.957137
# ...                                        ...                ...
# Contract to Close Days min     0 days 00:00:00   12 days 00:00:00
#                        25%    21 days 00:00:00   19 days 00:00:00
#                        50%    28 days 00:00:00   23 days 00:00:00
#                        75%    35 days 12:00:00   30 days 12:00:00
#                        max    97 days 00:00:00  142 days 00:00:00
#
# [64 rows x 63 columns]
#
# Sold Grouped by CountyOrParish:
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# c:\Users\matth\Documents\IDX_Exchange\Work\.venv\Lib\site-packages\pandas\core\nanops.py:1027: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
# CountyOrParish                          Alameda            Alpine  \
# Price Ratio            count            19504.0               1.0
#                        mean            1.241041          0.666667
#                        std            13.043801               NaN
#                        min             0.000536          0.666667
#                        25%             0.973771          0.666667
# ...                                         ...               ...
# Contract to Close Days min      0 days 00:00:00  32 days 00:00:00
#                        25%     18 days 00:00:00  32 days 00:00:00
#                        50%     23 days 00:00:00  32 days 00:00:00
#                        75%     30 days 00:00:00  32 days 00:00:00
#                        max    622 days 00:00:00  32 days 00:00:00
#
# CountyOrParish                           Amador              Butte  \
# Price Ratio            count               23.0             4127.0
#                        mean            0.885287           1.465577
#                        std             0.114281          22.621502
#                        min             0.514032                0.1
#                        25%              0.85058           0.934864
# ...                                         ...                ...
# Contract to Close Days min      1 days 00:00:00    0 days 00:00:00
#                        25%     16 days 12:00:00   23 days 00:00:00
#                        50%     24 days 00:00:00   30 days 00:00:00
#                        75%     33 days 12:00:00   39 days 00:00:00
#                        max    107 days 00:00:00  749 days 00:00:00
#
# CountyOrParish                        Calaveras            Clark  \
# Price Ratio            count               94.0              1.0
#                        mean             0.92176         0.974026
#                        std             0.104776              NaN
#                        min             0.401713         0.974026
#                        25%             0.891327         0.974026
# ...                                         ...              ...
# Contract to Close Days min      0 days 00:00:00  9 days 00:00:00
#                        25%     17 days 00:00:00  9 days 00:00:00
#                        50%     29 days 00:00:00  9 days 00:00:00
#                        75%     36 days 00:00:00  9 days 00:00:00
#                        max    156 days 00:00:00  9 days 00:00:00
#
# CountyOrParish                          Colusa        Contra Costa  \
# Price Ratio            count              24.0             18818.0
#                        mean           0.943039            1.059856
#                        std            0.122577            7.207569
#                        min               0.625             0.00044
#                        25%            0.888694            0.961538
# ...                                        ...                 ...
# Contract to Close Days min    16 days 00:00:00     0 days 00:00:00
#                        25%    20 days 00:00:00    18 days 00:00:00
#                        50%    28 days 00:00:00    23 days 00:00:00
#                        75%    37 days 18:00:00    30 days 00:00:00
#                        max    75 days 00:00:00  1568 days 00:00:00
#
# CountyOrParish                      Del Norte          El Dorado  ...  \
# Price Ratio            count              1.0               88.0  ...
#                        mean          0.764615           0.944341  ...
#                        std                NaN           0.097953  ...
#                        min           0.764615           0.548589  ...
#                        25%           0.764615            0.89936  ...
# ...                                       ...                ...  ...
# Contract to Close Days min    9 days 00:00:00    0 days 00:00:00  ...
#                        25%    9 days 00:00:00   20 days 18:00:00  ...
#                        50%    9 days 00:00:00   27 days 00:00:00  ...
#                        75%    9 days 00:00:00   34 days 00:00:00  ...
#                        max    9 days 00:00:00  101 days 00:00:00  ...
#
# CountyOrParish                           Sonoma         Stanislaus  \
# Price Ratio            count              159.0              630.0
#                        mean            0.967456           0.996813
#                        std             0.106178           0.416376
#                        min                0.625           0.258065
#                        25%             0.927814           0.953017
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    0 days 00:00:00
#                        25%     19 days 00:00:00   21 days 00:00:00
#                        50%     23 days 00:00:00   28 days 12:00:00
#                        75%     32 days 00:00:00   35 days 06:00:00
#                        max    117 days 00:00:00  139 days 00:00:00
#
# CountyOrParish                          Sutter             Tehama  \
# Price Ratio            count              96.0              402.0
#                        mean          18.431382           0.940394
#                        std          122.016654           0.131021
#                        min            0.099338           0.107554
#                        25%            0.954158           0.895569
# ...                                        ...                ...
# Contract to Close Days min     4 days 00:00:00    0 days 00:00:00
#                        25%    21 days 00:00:00   27 days 00:00:00
#                        50%    27 days 00:00:00   32 days 00:00:00
#                        75%    34 days 06:00:00   45 days 18:00:00
#                        max    48 days 00:00:00  560 days 00:00:00
#
# CountyOrParish                         Trinity             Tulare  \
# Price Ratio            count              34.0              361.0
#                        mean            0.89316          13.863418
#                        std            0.105662         109.284574
#                        min            0.645161           0.093633
#                        25%            0.846468           0.940344
# ...                                        ...                ...
# Contract to Close Days min     1 days 00:00:00    0 days 00:00:00
#                        25%    25 days 00:00:00   23 days 00:00:00
#                        50%    32 days 12:00:00   31 days 00:00:00
#                        75%    48 days 12:00:00   41 days 00:00:00
#                        max    95 days 00:00:00  163 days 00:00:00
#
# CountyOrParish                         Tuolumne            Ventura  \
# Price Ratio            count               80.0            12862.0
#                        mean            0.922429           1.479694
#                        std             0.128662          22.885583
#                        min             0.238095            0.00098
#                        25%             0.881063           0.955917
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    0 days 00:00:00
#                        25%     24 days 00:00:00   11 days 00:00:00
#                        50%     31 days 00:00:00   24 days 00:00:00
#                        75%     40 days 12:00:00   34 days 00:00:00
#                        max    200 days 00:00:00  535 days 00:00:00
#
# CountyOrParish                             Yolo               Yuba
# Price Ratio            count               89.0              158.0
#                        mean            0.981657           0.949736
#                        std             0.079704           0.090396
#                        min             0.836364                0.5
#                        25%             0.948276           0.917542
# ...                                         ...                ...
# Contract to Close Days min      0 days 00:00:00    6 days 00:00:00
#                        25%     21 days 00:00:00   22 days 06:00:00
#                        50%     28 days 00:00:00   30 days 00:00:00
#                        75%     40 days 00:00:00   39 days 00:00:00
#                        max    172 days 00:00:00  164 days 00:00:00
#
# [64 rows x 63 columns]

# %%
listing.to_csv("listing+features.csv", index=False)

sold.to_csv("sold+features.csv", index=False)

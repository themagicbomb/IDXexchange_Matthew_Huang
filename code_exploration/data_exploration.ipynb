# %%
import pandas as pd
import numpy as np

# %%
# Listing Dataframes below
listing202401 = pd.read_csv("data/CRMLSListing202401.csv")
listing202402 = pd.read_csv("data/CRMLSListing202402.csv")
listing202403 = pd.read_csv("data/CRMLSListing202403.csv")
listing202404 = pd.read_csv("data/CRMLSListing202404.csv")
listing202405 = pd.read_csv("data/CRMLSListing202405.csv")
listing202406 = pd.read_csv("data/CRMLSListing202406.csv")
listing202407 = pd.read_csv("data/CRMLSListing202407.csv")
listing202408 = pd.read_csv("data/CRMLSListing202408.csv")
listing202409 = pd.read_csv("data/CRMLSListing202409.csv")
listing202410 = pd.read_csv("data/CRMLSListing202410.csv")
listing202411 = pd.read_csv("data/CRMLSListing202411.csv")
listing202412 = pd.read_csv("data/CRMLSListing202412.csv")

listing202501 = pd.read_csv("data/CRMLSListing202501.csv")
listing202502 = pd.read_csv("data/CRMLSListing202502.csv")
listing202503 = pd.read_csv("data/CRMLSListing202503.csv")
listing202504 = pd.read_csv("data/CRMLSListing202504.csv")
listing202505 = pd.read_csv("data/CRMLSListing202505.csv")
listing202506 = pd.read_csv("data/CRMLSListing202506.csv")
listing202507 = pd.read_csv("data/CRMLSListing202507.csv")
listing202508 = pd.read_csv("data/CRMLSListing202508.csv")
listing202509 = pd.read_csv("data/CRMLSListing202509.csv")
listing202510 = pd.read_csv("data/CRMLSListing202510.csv")
listing202511 = pd.read_csv("data/CRMLSListing202511.csv")
listing202512 = pd.read_csv("data/CRMLSListing202512.csv")

listing202601 = pd.read_csv("data/CRMLSListing202601.csv")
listing202602 = pd.read_csv("data/CRMLSListing202602.csv", encoding='cp1252')
listing202603 = pd.read_csv("data/CRMLSListing202603.csv", encoding='cp1252')

# %%
# Sold Dataframes below
sold202401 = pd.read_csv("data/CRMLSSold202401.csv")
sold202402 = pd.read_csv("data/CRMLSSold202402.csv")
sold202403 = pd.read_csv("data/CRMLSSold202403.csv")
sold202404 = pd.read_csv("data/CRMLSSold202404.csv", low_memory=False) # mixed types
sold202405 = pd.read_csv("data/CRMLSSold202405.csv")
sold202406 = pd.read_csv("data/CRMLSSold202406.csv")
sold202407 = pd.read_csv("data/CRMLSSold202407.csv")
sold202408 = pd.read_csv("data/CRMLSSold202408.csv")
sold202409 = pd.read_csv("data/CRMLSSold202409.csv")
sold202410 = pd.read_csv("data/CRMLSSold202410.csv")
sold202411 = pd.read_csv("data/CRMLSSold202411.csv")
sold202412 = pd.read_csv("data/CRMLSSold202412.csv")

sold202501 = pd.read_csv("data/CRMLSSold202501.csv")
sold202502 = pd.read_csv("data/CRMLSSold202502.csv")
sold202503 = pd.read_csv("data/CRMLSSold202503.csv")
sold202504 = pd.read_csv("data/CRMLSSold202504.csv")
sold202505 = pd.read_csv("data/CRMLSSold202505.csv")
sold202506 = pd.read_csv("data/CRMLSSold202506.csv", low_memory=False) # mixed types
sold202507 = pd.read_csv("data/CRMLSSold202507.csv")
sold202508 = pd.read_csv("data/CRMLSSold202508.csv")
sold202509 = pd.read_csv("data/CRMLSSold202509.csv")
sold202510 = pd.read_csv("data/CRMLSSold202510.csv")
sold202511 = pd.read_csv("data/CRMLSSold202511.csv")
sold202512 = pd.read_csv("data/CRMLSSold202512.csv")

sold202601 = pd.read_csv("data/CRMLSSold202601.csv", low_memory=False) # mixed types
sold202602 = pd.read_csv("data/CRMLSSold202602.csv", encoding='cp1252')
sold202603 = pd.read_csv("data/CRMLSSold202603.csv", encoding='cp1252')

# %%
print("Jan 2024 equal Feb 2024 columns:", all(listing202401.columns == listing202402.columns))
print("Jan 2024 equal Mar 2024 columns:", all(listing202401.columns == listing202403.columns))
print("Jan 2024 equal Apr 2024 columns:", all(listing202401.columns == listing202404.columns))
print("JAN 2024 NOT EQUAL TO MAY 2024 COLUMNS\n")
#print("Jan 2024 equal May 2024 columns:", all(listing202401.columns == listing202405.columns)) ERROR! mismatch lengths, extra columns

print("May 2024 equal June 2024 columns:", all(listing202405.columns == listing202406.columns))
print("May 2024 equal Jul 2024 columns:", all(listing202405.columns == listing202407.columns))
print("May 2024 equal Aug 2024 columns:", all(listing202405.columns == listing202408.columns))
print("May 2024 equal Sep 2024 columns:", all(listing202405.columns == listing202409.columns))
print("May 2024 equal Oct 2024 columns:", all(listing202405.columns == listing202410.columns))
print("May 2024 equal Nov 2024 columns:", all(listing202405.columns == listing202411.columns))
print("May 2024 equal Dec 2024 columns:", all(listing202405.columns == listing202412.columns))
print("May 2024 equal Jan 2025 columns:", all(listing202405.columns == listing202501.columns))
print("May 2024 equal Feb 2025 columns:", all(listing202405.columns == listing202502.columns))
print("May 2024 equal Mar 2025 columns:", all(listing202405.columns == listing202503.columns))
print("May 2024 equal Apr 2025 columns:", all(listing202405.columns == listing202504.columns))
print("May 2024 equal May 2025 columns:", all(listing202405.columns == listing202505.columns))
print("May 2024 equal Jun 2025 columns:", all(listing202405.columns == listing202506.columns))
print("May 2024 equal Jul 2025 columns:", all(listing202405.columns == listing202507.columns))
print("May 2024 equal Aug 2025 columns:", all(listing202405.columns == listing202508.columns))
print("May 2024 equal Sep 2025 columns:", all(listing202405.columns == listing202509.columns))
print("May 2024 equal Oct 2025 columns:", all(listing202405.columns == listing202510.columns))
print("May 2024 equal Nov 2025 columns:", all(listing202405.columns == listing202511.columns))
print("May 2024 equal Dec 2025 columns:", all(listing202405.columns == listing202512.columns))
print("May 2024 equal Jan 2026 columns:", all(listing202405.columns == listing202601.columns))
print("FEB 2025 NOT EQUAL TO JAN 2024 OR MAY 2024 COLUMNS\n")
#print("May 2024 equal Feb 2026 columns:", all(listing202405.columns == listing202602.columns)) ERROR! mismatch lengths, extra columns
#print("Jan 2024 equal Feb 2026 columns:", all(listing202401.columns == listing202602.columns)) ERROR! mismatch lengths, extra columns

print("Feb 2026 equal Mar 2026 columns:", all(listing202602.columns == listing202603.columns))
# Out:
# Jan 2024 equal Feb 2024 columns: True
# Jan 2024 equal Mar 2024 columns: True
# Jan 2024 equal Apr 2024 columns: True
# JAN 2024 NOT EQUAL TO MAY 2024 COLUMNS
#
# May 2024 equal June 2024 columns: True
# May 2024 equal Jul 2024 columns: True
# May 2024 equal Aug 2024 columns: True
# May 2024 equal Sep 2024 columns: True
# May 2024 equal Oct 2024 columns: True
# May 2024 equal Nov 2024 columns: True
# May 2024 equal Dec 2024 columns: True
# May 2024 equal Jan 2025 columns: True
# May 2024 equal Feb 2025 columns: True
# May 2024 equal Mar 2025 columns: True
# May 2024 equal Apr 2025 columns: True
# May 2024 equal May 2025 columns: True
# May 2024 equal Jun 2025 columns: True
# May 2024 equal Jul 2025 columns: True
# May 2024 equal Aug 2025 columns: True
# May 2024 equal Sep 2025 columns: True
# May 2024 equal Oct 2025 columns: True
# May 2024 equal Nov 2025 columns: True
# May 2024 equal Dec 2025 columns: True
# May 2024 equal Jan 2026 columns: True
# ...

# %% [markdown]
# RESULT (Listing):
# - Jan 2024 - Apr 2024 same format
# - May 2024 - Jan 2026 same format
# - Feb 2025 - Mar 2026 same format
#
# NOTE: 3 formats have different number of columns

# %%
#print("Jan 2024 equal Feb 2024 columns:", all(sold202401.columns == sold202402.columns)) ERROR! mismatch lengths, extra columns
print("JAN 2024 NOT EQUAL TO FEB 2024 COLUMNS\n")

print("Feb 2024 equal Mar 2024 columns:", all(sold202402.columns == sold202403.columns))
print("Feb 2024 equal Apr 2024 columns:", all(sold202402.columns == sold202404.columns))
#print("Feb 2024 equal May 2024 columns:", all(sold202402.columns == sold202405.columns)) ERROR! mismatch lengths, extra columns
print("Jan 2024 equal May 2024 columns:", all(sold202401.columns == sold202405.columns))
print("MAY 2024 NOT EQUAL TO JAN 2024 OR FEB 2024 COLUMNS\n")

print("May 2024 equal Jun 2024 columns:", all(sold202405.columns == sold202406.columns))
print("May 2024 equal Jul 2024 columns:", all(sold202405.columns == sold202407.columns))
print("****May 2024 equal May 2025 columns:", all(sold202405.columns == sold202501.columns))
#print("May 2024 equal Aug 2024 columns:", all(sold202405.columns == sold202408.columns)) ERROR! mismatch lengths, extra columns
#print("Jan 2024 equal Aug 2024 columns:", all(sold202401.columns == sold202408.columns)) ERROR! mismatch lengths, extra columns
print("Feb 2024 equal Aug 2024 columns:", all(sold202402.columns == sold202408.columns))
print("AUG 2024 NOT EQUAL TO JAN 2024 OR FEB 2024 OR MAY 2024 COLUMNS\n")

print("Aug 2024 equal Sep 2024 columns:", all(sold202408.columns == sold202409.columns))
print("Aug 2024 equal Oct 2024 columns:", all(sold202408.columns == sold202410.columns))
print("Aug 2024 equal Nov 2024 columns:", all(sold202408.columns == sold202411.columns))
print("Aug 2024 equal Dec 2024 columns:", all(sold202408.columns == sold202412.columns))
#print("Aug 2024 equal Jan 2025 columns:", all(sold202408.columns == sold202501.columns)) ERROR! mismatch lengths, extra columns
print("Aug 2024 equal Feb 2025 columns:", all(sold202408.columns == sold202502.columns))
print("Aug 2024 equal Mar 2025 columns:", all(sold202408.columns == sold202503.columns))
print("Aug 2024 equal Apr 2025 columns:", all(sold202408.columns == sold202504.columns))
print("Aug 2024 equal May 2025 columns:", all(sold202408.columns == sold202505.columns))
print("Aug 2024 equal Jun 2025 columns:", all(sold202408.columns == sold202506.columns))
print("Aug 2024 equal Jul 2025 columns:", all(sold202408.columns == sold202507.columns))
print("Aug 2024 equal Aug 2025 columns:", all(sold202408.columns == sold202508.columns))
print("Aug 2024 equal Sep 2025 columns:", all(sold202408.columns == sold202509.columns))
print("Aug 2024 equal Oct 2025 columns:", all(sold202408.columns == sold202510.columns))
print("Aug 2024 equal Nov 2025 columns:", all(sold202408.columns == sold202511.columns))
print("Aug 2024 equal Dec 2025 columns:", all(sold202408.columns == sold202512.columns))
print("Aug 2024 equal Jan 2026 columns:", all(sold202408.columns == sold202601.columns))
#print("Aug 2024 equal Feb 2026 columns:", all(sold202408.columns == sold202602.columns)) ERROR! mismatch lengths, extra columns
#print("May 2024 equal Feb 2026 columns:", all(sold202405.columns == sold202602.columns))
#print("Feb 2024 equal Feb 2026 columns:", all(sold202402.columns == sold202602.columns))
#print("Jan 2024 equal Feb 2026 columns:", all(sold202401.columns == sold202602.columns))
print("FEB 2026 NOT EQUAL TO JAN 2024 OR FEB 2024 OR MAY 2024 OR AUG 2024 COLUMNS\n")

print("Feb 2026 equal Mar 2026 columns:", all(sold202602.columns == sold202603.columns))
# Out:
# JAN 2024 NOT EQUAL TO FEB 2024 COLUMNS
#
# Feb 2024 equal Mar 2024 columns: True
# Feb 2024 equal Apr 2024 columns: True
# Jan 2024 equal May 2024 columns: False
# MAY 2024 NOT EQUAL TO JAN 2024 OR FEB 2024 COLUMNS
#
# May 2024 equal Jun 2024 columns: True
# May 2024 equal Jul 2024 columns: True
# ****May 2024 equal May 2025 columns: True
# Feb 2024 equal Aug 2024 columns: False
# AUG 2024 NOT EQUAL TO JAN 2024 OR FEB 2024 OR MAY 2024 COLUMNS
#
# Aug 2024 equal Sep 2024 columns: True
# Aug 2024 equal Oct 2024 columns: True
# Aug 2024 equal Nov 2024 columns: True
# Aug 2024 equal Dec 2024 columns: True
# Aug 2024 equal Feb 2025 columns: True
# Aug 2024 equal Mar 2025 columns: True
# Aug 2024 equal Apr 2025 columns: True
# Aug 2024 equal May 2025 columns: True
# Aug 2024 equal Jun 2025 columns: True
# Aug 2024 equal Jul 2025 columns: True
# Aug 2024 equal Aug 2025 columns: True
# Aug 2024 equal Sep 2025 columns: True
# Aug 2024 equal Oct 2025 columns: True
# ...

# %% [markdown]
# RESULT (Sold):
# - Jan 2024 unique format
# - Feb 2024 - Apr 2024 same format
# - May 2024 - Jul 2024 & May 2025 same format, but same # cols as Jan 2024
# - Aug 2024 - Jan 2026 same format, but same # cols as Feb 2024
# - Feb 2026 - Mar 2026 same format
#
# NOTE: 5 formats, but May 2024 may have mixed up columns with Jan 2024 and Aug 2024 with Feb 2024

# %%
listing = pd.concat([listing202401, listing202402, listing202403, listing202404, listing202405, listing202406,
                     listing202407, listing202408, listing202409, listing202410, listing202411, listing202412,
                     listing202501, listing202502, listing202503, listing202504, listing202505, listing202506,
                     listing202507, listing202508, listing202509, listing202510, listing202511, listing202512,
                     listing202601, listing202602, listing202603], ignore_index=True)

sold = pd.concat([sold202401, sold202402, sold202403, sold202404, sold202405, sold202406,
                  sold202407, sold202408, sold202409, sold202410, sold202411, sold202412,
                  sold202501, sold202502, sold202503, sold202504, sold202505, sold202506,
                  sold202507, sold202508, sold202509, sold202510, sold202511, sold202512,
                  sold202601, sold202602, sold202603], ignore_index=True)

# %%
listing.columns.sort_values()
# simular columns possibly to be combined:
    # BathroomsTotalInteger & BedroomsTotal,
    # BuyerAgencyCompensation & BuyerAgencyCompensationType
    # BuyerOfficeName & BuyerOfficeName.1
    # CloseDate & CloseDate.1
    # DaysOnMarket & DaysOnMarket.1
    # Latitude & Latitude.1
    # ListAgentFirstName & ListAgentFirstName.1
    # ListAgentLastName & ListAgentLastName.1
    # ListPrice & ListPrice.1
    # LivingArea & LivingArea.1
    # Longitude & Longitude.1
    # PropertyType & PropertyType.1
    # UnparsedAddress & UnparsedAddress.1
# Out:
# Index(['AboveGradeFinishedArea', 'AssociationFee', 'AssociationFeeFrequency',
#        'AttachedGarageYN', 'BathroomsTotalInteger', 'BedroomsTotal',
#        'BelowGradeFinishedArea', 'BuilderName', 'BuildingAreaTotal',
#        'BusinessType', 'BuyerAgencyCompensation',
#        'BuyerAgencyCompensationType', 'BuyerAgentFirstName',
#        'BuyerAgentLastName', 'BuyerAgentMlsId', 'BuyerOfficeAOR',
#        'BuyerOfficeName', 'BuyerOfficeName.1', 'City', 'CloseDate',
#        'CloseDate.1', 'ClosePrice', 'CoBuyerAgentFirstName',
#        'CoListAgentFirstName', 'CoListAgentLastName', 'CoListOfficeName',
#        'ContractStatusChangeDate', 'CountyOrParish', 'CoveredSpaces',
#        'DaysOnMarket', 'DaysOnMarket.1', 'ElementarySchool',
#        'ElementarySchoolDistrict', 'FireplaceYN', 'FireplacesTotal',
#        'GarageSpaces', 'HighSchool', 'HighSchoolDistrict', 'Latitude',
#        'Latitude.1', 'Levels', 'ListAgentEmail', 'ListAgentFirstName',
# ...

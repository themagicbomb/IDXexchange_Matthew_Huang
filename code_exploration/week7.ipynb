# %% [markdown]
# Q1 = df['ClosePrice'].quantile(0.25)
#
# Q3 = df['ClosePrice'].quantile(0.75)
#
# IQR = Q3 - Q1
#
# lower = Q1 - 1.5 * IQR
#
# upper = Q3 + 1.5 * IQR
#
# df = df[(df['ClosePrice'] >= lower) & (df['ClosePrice'] <= upper)]

# %% [markdown]
# Submit a .py script applying IQR filtering to key numeric fields (ClosePrice, LivingArea, DaysOnMarket). Add outlier flag columns rather than deleting records outright. Save both a full flagged dataset and a clean filtered dataset. Include a written comparison of dataset size and median values before and after filtering.

# %%
import pandas as pd

# %%
listing = pd.read_csv("data/listing+features.csv", low_memory=False)
sold = pd.read_csv("data/sold+features.csv", low_memory=False)

# %%
for df in (listing, sold):
    for var in ("ClosePrice", "LivingArea", "DaysOnMarket"):
        Q1 = df[var].quantile(0.25)
        Q3 = df[var].quantile(0.75)

        IQR = Q3 - Q1

        lower = Q1 - 1.5 * IQR

        upper = Q3 + 1.5 * IQR

        df[var + "_in_IQR_Flag"] = (df[var] >= lower) & (df[var] <= upper)

# %%
filtered_listing = listing[listing[["ClosePrice_in_IQR_Flag", "LivingArea_in_IQR_Flag", "DaysOnMarket_in_IQR_Flag"]].all(axis = 1)]

filtered_sold = sold[sold[["ClosePrice_in_IQR_Flag", "LivingArea_in_IQR_Flag", "DaysOnMarket_in_IQR_Flag"]].all(axis = 1)]

# %%
print("Listing Dataset Size before IQR Filtering:", listing.shape[0])
print("Listing Variable Medians before IQR Filtering:")
print(listing.select_dtypes("number").median())
# Out:
# Listing Dataset Size before IQR Filtering: 565727
# Listing Variable Medians before IQR Filtering:
# OriginalListPrice               8.490000e+05
# ListingKey                      1.107761e+09
# ClosePrice                      8.550000e+05
# Latitude                        3.405497e+01
# Longitude                      -1.180329e+02
# LivingArea                      1.671000e+03
# ListPrice                       8.450000e+05
# DaysOnMarket                    1.100000e+01
# ParkingTotal                    2.000000e+00
# YearBuilt                       1.980000e+03
# StreetNumberNumeric             3.265000e+03
# BathroomsTotalInteger           2.000000e+00
# BuyerAgencyCompensation         2.500000e+00
# BedroomsTotal                   3.000000e+00
# Stories                         1.000000e+00
# MainLevelBedrooms               2.000000e+00
# GarageSpaces                    2.000000e+00
# AssociationFee                  1.250000e+02
# LotSizeSquareFeet               7.405000e+03
# rate_30yr_fixed                 6.715000e+00
# Price Ratio                     1.000000e+00
# Price Per Sq Ft                 5.637255e+02
# Days on Market                  1.100000e+01
# Year                            2.025000e+03
# Month                           6.000000e+00
# Close to Original List Ratio    1.000000e+00
# dtype: float64

# %%
print("\nListing Dataset Size after IQR Filtering:", filtered_listing.shape[0])
print("Listing Variable Medians after IQR Filtering:")
print(filtered_listing.select_dtypes("number").median())
# Out:
# Listing Dataset Size after IQR Filtering: 114717
# Listing Variable Medians after IQR Filtering:
# OriginalListPrice               8.150000e+05
# ListingKey                      1.118993e+09
# ClosePrice                      8.270000e+05
# Latitude                        3.403323e+01
# Longitude                      -1.180087e+02
# LivingArea                      1.555000e+03
# ListPrice                       8.100000e+05
# DaysOnMarket                    9.000000e+00
# ParkingTotal                    2.000000e+00
# YearBuilt                       1.977000e+03
# StreetNumberNumeric             3.134000e+03
# BathroomsTotalInteger           2.000000e+00
# BuyerAgencyCompensation         2.500000e+00
# BedroomsTotal                   3.000000e+00
# Stories                         1.000000e+00
# MainLevelBedrooms               2.000000e+00
# GarageSpaces                    2.000000e+00
# AssociationFee                  8.100000e+01
# LotSizeSquareFeet               6.970000e+03
# rate_30yr_fixed                 6.642500e+00
# Price Ratio                     1.000000e+00
# Price Per Sq Ft                 5.568562e+02
# Days on Market                  9.000000e+00
# Year                            2.025000e+03
# Month                           6.000000e+00
# Close to Original List Ratio    1.000000e+00
# dtype: float64

# %%
print("\nSold Dataset Size before IQR Filtering:", sold.shape[0])
print("Sold Variable Medians before IQR Filtering:")
print(sold.select_dtypes("number").median())
# Out:
# Sold Dataset Size before IQR Filtering: 413477
# Sold Variable Medians before IQR Filtering:
# OriginalListPrice               8.250000e+05
# ListingKey                      1.097308e+09
# ClosePrice                      8.210000e+05
# Latitude                        3.404633e+01
# Longitude                      -1.180139e+02
# LivingArea                      1.643000e+03
# ListPrice                       8.150000e+05
# DaysOnMarket                    1.800000e+01
# ParkingTotal                    2.000000e+00
# YearBuilt                       1.979000e+03
# StreetNumberNumeric             3.307000e+03
# BathroomsTotalInteger           2.000000e+00
# BedroomsTotal                   3.000000e+00
# Stories                         1.000000e+00
# MainLevelBedrooms               2.000000e+00
# GarageSpaces                    2.000000e+00
# AssociationFee                  9.500000e+01
# LotSizeSquareFeet               7.245000e+03
# BuyerAgencyCompensation         2.500000e+00
# rate_30yr_fixed                 6.715000e+00
# Price Ratio                     9.956411e-01
# Price Per Sq Ft                 5.371610e+02
# Days on Market                  1.800000e+01
# Year                            2.025000e+03
# Month                           6.000000e+00
# Close to Original List Ratio    9.956411e-01
# dtype: float64

# %%
print("\nSold Dataset Size after IQR Filtering:", filtered_sold.shape[0])
print("Sold Variable Medians after IQR Filtering:")
print(filtered_sold.select_dtypes("number").median())
# Out:
# Sold Dataset Size after IQR Filtering: 348494
# Sold Variable Medians after IQR Filtering:
# OriginalListPrice               7.900000e+05
# ListingKey                      1.098775e+09
# ClosePrice                      7.850000e+05
# Latitude                        3.404026e+01
# Longitude                      -1.179937e+02
# LivingArea                      1.569000e+03
# ListPrice                       7.850000e+05
# DaysOnMarket                    1.600000e+01
# ParkingTotal                    2.000000e+00
# YearBuilt                       1.978000e+03
# StreetNumberNumeric             3.417000e+03
# BathroomsTotalInteger           2.000000e+00
# BedroomsTotal                   3.000000e+00
# Stories                         1.000000e+00
# MainLevelBedrooms               2.000000e+00
# GarageSpaces                    2.000000e+00
# AssociationFee                  8.700000e+01
# LotSizeSquareFeet               7.002000e+03
# BuyerAgencyCompensation         2.500000e+00
# rate_30yr_fixed                 6.715000e+00
# Price Ratio                     1.000000e+00
# Price Per Sq Ft                 5.269231e+02
# Days on Market                  1.600000e+01
# Year                            2.025000e+03
# Month                           6.000000e+00
# Close to Original List Ratio    1.000000e+00
# dtype: float64

# %%
print("\nSaving CSVs...")

sold.to_csv("sold_final_flagged.csv", index = False)
listing.to_csv("lising_final_flagged.csv", index = False)

filtered_sold.to_csv("sold_final_filtered.csv", index = False)
filtered_listing.to_csv("lising_final_filtered.csv", index = False)

print("Done!")
# Out:
# Saving CSVs...
# Done!
